# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in a:\projects\mtf_trading_system\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in a:\projects\mtf_trading_system\.venv\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline
import plotly.express as px 
from sklearn.preprocessing import MinMaxScaler

# %%
ticker = 'NCC.NS'

start_date = '2012-01-01'

end_date = datetime.now().strftime('%Y-%m-%d')



# Fetch the data

ncc = yf.download(ticker, start=start_date, end=end_date)

print(ncc)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_23164\580258168.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   ncc = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open   Volume
# Ticker          NCC.NS      NCC.NS      NCC.NS      NCC.NS   NCC.NS
# Date
# 2012-01-02   17.923101   18.107063   17.423779   17.765421   230279
# 2012-01-03   19.394794   19.499915   17.870542   18.080785  1092938
# 2012-01-04   18.842911   19.578755   18.632668   19.578755   552703
# 2012-01-05   18.080784   19.158272   17.923102   18.895471   594078
# 2012-01-06   18.553829   18.711511   17.817983   18.343588   315582
# ...                ...         ...         ...         ...      ...
# 2025-12-02  172.259995  172.899994  170.110001  171.020004  2853982
# 2025-12-03  168.949997  172.350006  168.100006  172.259995  3266458
# 2025-12-04  169.479996  170.720001  167.759995  168.949997  1620535
# 2025-12-05  168.160004  170.470001  167.000000  170.100006  1877824
# 2025-12-08  162.889999  168.610001  161.429993  168.000000  3293231
#
# [3438 rows x 5 columns]

# %%
ncc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3438 entries, 2012-01-02 to 2025-12-08
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Close, NCC.NS)   3438 non-null   float64
#  1   (High, NCC.NS)    3438 non-null   float64
#  2   (Low, NCC.NS)     3438 non-null   float64
#  3   (Open, NCC.NS)    3438 non-null   float64
#  4   (Volume, NCC.NS)  3438 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 161.2 KB

# %%
ncc.columns = [col[0] for col in ncc.columns]

# %%
ncc.head()
# Out:
#                 Close       High        Low       Open   Volume
# Date
# 2012-01-02  17.923101  18.107063  17.423779  17.765421   230279
# 2012-01-03  19.394794  19.499915  17.870542  18.080785  1092938
# 2012-01-04  18.842911  19.578755  18.632668  19.578755   552703
# 2012-01-05  18.080784  19.158272  17.923102  18.895471   594078
# 2012-01-06  18.553829  18.711511  17.817983  18.343588   315582

# %%
# Create the interactive line plot for 'Close' prices

fig = px.line(ncc, x=ncc.index, y='Close', title='NCC Closing Prices',

              labels={'Close': 'Price', 'Date': 'Date'})



# Show the plot

fig.show()

# %%
ncc_close = ncc['Close'].values
ncc_close
# Out:
# array([ 17.92310143,  19.39479446,  18.84291077, ..., 169.47999573,
#        168.16000366, 162.88999939], shape=(3438,))

# %%
train_data_len = int(np.ceil( len(ncc_close)-60))
ncc_close= ncc_close.reshape(-1, 1)

ncc_close
# Out:
# array([[ 17.92310143],
#        [ 19.39479446],
#        [ 18.84291077],
#        ...,
#        [169.47999573],
#        [168.16000366],
#        [162.88999939]], shape=(3438, 1))

# %%
scaler = MinMaxScaler(feature_range=(0,1))


scaled_data = scaler.fit_transform(ncc_close)

# %%
# Create the training data set 

# Create the scaled training data set

train_data = scaled_data[0:int(train_data_len), :]

# Split the data into x_train and y_train data sets

x_train = []

y_train = []



for i in range(60, len(train_data)):

    x_train.append(train_data[i-60:i, 0])

    y_train.append(train_data[i, 0])

    if i<= 61:

        print(x_train)

        print(y_train)

        print()

        

# Convert the x_train and y_train to numpy arrays 

x_train, y_train = np.array(x_train), np.array(y_train)



# Reshape the data  -- [samples, time steps, features].

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Out:
# [array([0.02626712, 0.03055697, 0.02894828, 0.02672675, 0.02810564,
#        0.03032716, 0.0329317 , 0.03553624, 0.0384472 , 0.03974948,
#        0.0420476 , 0.04373291, 0.04059213, 0.04434573, 0.04878878,
#        0.05024427, 0.05752168, 0.05813451, 0.06112208, 0.05491712,
#        0.06119868, 0.06464585, 0.06633118, 0.06878249, 0.06839947,
#        0.05361486, 0.05300203, 0.05690885, 0.05560656, 0.06204133,
#        0.06931873, 0.06862929, 0.06633118, 0.07123385, 0.07268932,
#        0.06556514, 0.06165832, 0.05874735, 0.05476392, 0.06050926,
#        0.06541194, 0.06456929, 0.06748025, 0.06564172, 0.05928359,
#        0.06127529, 0.06395644, 0.06587155, 0.06594814, 0.0653353 ,
#        0.06165832, 0.05721527, 0.05200617, 0.05369146, 0.05568319,
#        0.05154655, 0.05070389, 0.04664386, 0.04511178, 0.04587783])]
# [np.float64(0.05254240250345224)]
#
# [array([0.02626712, 0.03055697, 0.02894828, 0.02672675, 0.02810564,
#        0.03032716, 0.0329317 , 0.03553624, 0.0384472 , 0.03974948,
#        0.0420476 , 0.04373291, 0.04059213, 0.04434573, 0.04878878,
#        0.05024427, 0.05752168, 0.05813451, 0.06112208, 0.05491712,
#        0.06119868, 0.06464585, 0.06633118, 0.06878249, 0.06839947,
#        0.05361486, 0.05300203, 0.05690885, 0.05560656, 0.06204133,
#        0.06931873, 0.06862929, 0.06633118, 0.07123385, 0.07268932,
#        0.06556514, 0.06165832, 0.05874735, 0.05476392, 0.06050926,
#        0.06541194, 0.06456929, 0.06748025, 0.06564172, 0.05928359,
#        0.06127529, 0.06395644, 0.06587155, 0.06594814, 0.0653353 ,
#        0.06165832, 0.05721527, 0.05200617, 0.05369146, 0.05568319,
#        0.05154655, 0.05070389, 0.04664386, 0.04511178, 0.04587783]), array([0.03055697, 0.02894828, 0.02672675, 0.02810564, 0.03032716,
#        0.0329317 , 0.03553624, 0.0384472 , 0.03974948, 0.0420476 ,
#        0.04373291, 0.04059213, 0.04434573, 0.04878878, 0.05024427,
#        0.05752168, 0.05813451, 0.06112208, 0.05491712, 0.06119868,
#        0.06464585, 0.06633118, 0.06878249, 0.06839947, 0.05361486,
#        0.05300203, 0.05690885, 0.05560656, 0.06204133, 0.06931873,
#        0.06862929, 0.06633118, 0.07123385, 0.07268932, 0.06556514,
#        0.06165832, 0.05874735, 0.05476392, 0.06050926, 0.06541194,
#        0.06456929, 0.06748025, 0.06564172, 0.05928359, 0.06127529,
#        0.06395644, 0.06587155, 0.06594814, 0.0653353 , 0.06165832,
#        0.05721527, 0.05200617, 0.05369146, 0.05568319, 0.05154655,
#        0.05070389, 0.04664386, 0.04511178, 0.04587783, 0.0525424 ])]
# [np.float64(0.05254240250345224), np.float64(0.06035604735343497)]

# %%
# !pip install ta
# Out:
# Requirement already satisfied: ta in a:\projects\mtf_trading_system\.venv\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy in a:\projects\mtf_trading_system\.venv\lib\site-packages (from ta) (2.3.5)
# Requirement already satisfied: pandas in a:\projects\mtf_trading_system\.venv\lib\site-packages (from ta) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from pandas->ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: six>=1.5 in a:\projects\mtf_trading_system\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.17.0)

# %%
# ============================================================
# 📌 IMPORTS
# ============================================================
import numpy as np
import pandas as pd
import ta
import plotly.graph_objects as go
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, Conv1D, MaxPooling1D
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import warnings
warnings.filterwarnings("ignore")


# ============================================================
# 📌 FEATURE ENGINEERING
# ============================================================
def build_features(df):
    df = df.copy()

    df["EMA_20"] = df["Close"].ewm(span=20).mean()
    df["EMA_50"] = df["Close"].ewm(span=50).mean()
    df["RSI_14"] = ta.momentum.rsi(df["Close"], window=14)

    macd = ta.trend.MACD(df["Close"])
    df["MACD"] = macd.macd()

    df["Return"] = df["Close"].pct_change()
    df["Volatility"] = df["Return"].rolling(20).std()

    df["Target"] = df["Close"].rolling(7).mean().shift(-1)

    df = df.dropna()
    return df


# ============================================================
# 📌 CREATE SEQUENCES
# ============================================================
def create_sequences(data, target, time_steps):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps])
        y.append(target[i + time_steps])
    return np.array(X), np.array(y)


# ============================================================
# 📌 TRAINING PIPELINE — stores scalers inside df_processed.attrs
# ============================================================
def train_forecasting_model(df_raw):

    # ---------- Feature engineering ----------
    df = build_features(df_raw)

    # ---------- Train/Valid Split ----------
    split = int(len(df) * 0.85)
    train_df = df.iloc[:split]
    valid_df = df.iloc[split:]

    # ---------- Scaling ----------
    feature_cols = df.columns.drop("Target")

    scaler_x = MinMaxScaler()
    scaler_y = MinMaxScaler()

    X_train_scaled = scaler_x.fit_transform(train_df[feature_cols])
    X_valid_scaled = scaler_x.transform(valid_df[feature_cols])

    y_train_scaled = scaler_y.fit_transform(train_df[["Target"]])
    y_valid_scaled = scaler_y.transform(valid_df[["Target"]])

    # ---------- Sequence building ----------
    TIME_STEPS = 180

    X_train, y_train = create_sequences(X_train_scaled, y_train_scaled, TIME_STEPS)
    X_valid, y_valid = create_sequences(X_valid_scaled, y_valid_scaled, TIME_STEPS)

    X_train = np.array(X_train)
    X_valid = np.array(X_valid)

    # ---------- Model ----------
    model = Sequential([
        Conv1D(64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
        MaxPooling1D(pool_size=2),

        Bidirectional(LSTM(128, return_sequences=True)),
        Dropout(0.2),

        Bidirectional(LSTM(64)),
        Dropout(0.2),

        Dense(32, activation='relu'),
        Dense(1)
    ])

    model.compile(
        optimizer=AdamW(learning_rate=1e-3, weight_decay=1e-4),
        loss='mse'
    )

    early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.3, min_lr=1e-6)

    model.fit(
        X_train, y_train,
        validation_data=(X_valid, y_valid),
        epochs=150,
        batch_size=32,
        shuffle=True,
        callbacks=[early_stop, reduce_lr]
    )

    # ---------- Make Predictions ----------
    predictions_scaled = model.predict(X_valid)
    predictions = scaler_y.inverse_transform(predictions_scaled)

    actual = valid_df["Target"].values[TIME_STEPS:]
    actual = actual.reshape(-1, 1)

    # ---------- Save metadata ----------
    df.attrs["scaler_x"] = scaler_x
    df.attrs["scaler_y"] = scaler_y
    df.attrs["feature_cols"] = list(feature_cols)
    df.attrs["time_steps"] = TIME_STEPS

    return model, df, actual, predictions


# ============================================
# 📌 VISUALIZATION
# ============================================
def plot_forecast(df, actual, predictions):
    fig = go.Figure()

    # Actual prices
    fig.add_trace(go.Scatter(
        x=df.index[-len(actual):],
        y=actual.flatten(),
        name="Actual",
        mode="lines",
        line=dict(color="blue")
    ))

    # Predictions
    fig.add_trace(go.Scatter(
        x=df.index[-len(predictions):],
        y=predictions.flatten(),
        name="Predicted",
        mode="lines",
        line=dict(color="red")
    ))

    fig.update_layout(
        title="Stock Forecasting — Actual vs Predicted",
        xaxis_title="Date",
        yaxis_title="Price"
    )

    fig.show()

# ============================================
# Model Evaluation
# ============================================

def evaluate_model(df, actual, predictions, model, runs=50):

    # -----------------------------
    # Load attributes
    # -----------------------------
    scaler_x = df.attrs["scaler_x"]
    scaler_y = df.attrs["scaler_y"]
    feature_cols = df.attrs["feature_cols"]
    TIME_STEPS = df.attrs["time_steps"]

    # -----------------------------
    # Rebuild validation set
    # -----------------------------
    split = int(len(df) * 0.85)
    valid_df = df.iloc[split:]

    X_valid_scaled = scaler_x.transform(valid_df[feature_cols])
    y_dummy = np.zeros((len(valid_df), 1))

    X_valid, _ = create_sequences(X_valid_scaled, y_dummy, TIME_STEPS)
    X_valid = np.array(X_valid)

    # -----------------------------
    # Flatten arrays
    # -----------------------------
    actual = actual.flatten()
    predictions = predictions.flatten()

    # -----------------------------
    # Basic Metrics
    # -----------------------------
    mse = np.mean((actual - predictions) ** 2)
    rmse = float(np.sqrt(mse))
    mae = float(np.mean(np.abs(actual - predictions)))
    mape = float(np.mean(np.abs((actual - predictions) / actual)) * 100)

    # -----------------------------
    # Direction Accuracy
    # -----------------------------
    direction_actual = np.sign(np.diff(actual))
    direction_pred = np.sign(np.diff(predictions))
    direction_accuracy = float(np.mean(direction_actual == direction_pred) * 100)

    # -----------------------------
    # Confidence Level (Summary Only)
    # -----------------------------
    mc_std_list = []

    for _ in range(runs):
        preds_scaled = model(X_valid, training=True)
        preds = scaler_y.inverse_transform(preds_scaled).flatten()

        mc_std_list.append(np.std(preds))

    avg_uncertainty = float(np.mean(mc_std_list))

    # Convert uncertainty → confidence (inverse relationship)
    confidence_level = max(0, 100 - avg_uncertainty)

    # -----------------------------
    # FINAL CLEAN RETURN (APP READY)
    # -----------------------------
    return {
        "rmse": rmse,
        "mae": mae,
        "mape": mape,
        "direction_accuracy": direction_accuracy,
        "forecast_confidence": confidence_level     # single number %
    }




# ============================================================
# 📌 FUTURE FORECASTING — Only needs df_processed
# ============================================================
def forecast_future(model, df_processed, days=60):
    """
    Auto-regressive 60-day forecast.

    Uses:
      - model
      - df_processed (with attrs: scaler_x, scaler_y, feature_cols, time_steps)
    Returns:
      - list of predicted prices (float)
    """

    scaler_x = df_processed.attrs["scaler_x"]
    scaler_y = df_processed.attrs["scaler_y"]
    feature_cols = df_processed.attrs["feature_cols"]
    time_steps = df_processed.attrs["time_steps"]

    # Start from OHLCV only (no technicals, they’ll be recomputed)
    df_raw_future = df_processed[["Close", "High", "Low", "Open", "Volume"]].copy()

    future_predictions = []

    for _ in range(days):
        # 1) Rebuild technical indicators on full history
        df_feat = build_features(df_raw_future)

        # 2) Take last time_steps window of features
        last_block = df_feat[feature_cols].tail(time_steps)

        X_scaled = scaler_x.transform(last_block)
        X_input = X_scaled.reshape(1, time_steps, len(feature_cols))

        # 3) Predict next (scaled) target and invert
        next_scaled = model.predict(X_input, verbose=0)[0]
        next_unscaled = scaler_y.inverse_transform(next_scaled.reshape(-1, 1))[0, 0]

        # 4) Append new row: copy previous OHLCV, only change Close
        last_row = df_raw_future.iloc[-1].copy()
        next_date = df_raw_future.index[-1] + pd.Timedelta(days=1)

        last_row["Close"] = next_unscaled             # new predicted close
        # High / Low / Open / Volume stay same as last row (no NaNs)

        df_raw_future.loc[next_date] = last_row

        future_predictions.append(next_unscaled)

    return future_predictions




# ============================================================
# 📌 PLOT FUTURE FORECAST
# ============================================================
def plot_future(df_processed, future_preds):

    future_dates = pd.date_range(
        start=df_processed.index[-1] + pd.Timedelta(days=1),
        periods=len(future_preds)
    )

    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=df_processed.index,
        y=df_processed["Close"],
        name="Historical",
        line=dict(color="blue", width=2)
    ))

    fig.add_trace(go.Scatter(
        x=future_dates,
        y=future_preds,
        name="Next 60 Days Forecast",
        line=dict(color="red", width=3)
    ))

    fig.update_layout(
        title="60-Day Stock Price Forecast",
        xaxis_title="Date",
        yaxis_title="Price"
    )

    fig.show()

# %%
model, df_processed, actual, predictions = train_forecasting_model(ncc)

plot_forecast(df_processed, actual, predictions)
# Out:
# Epoch 1/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 21s 145ms/step - loss: 0.0085 - val_loss: 0.1254 - learning_rate: 0.0010
# Epoch 2/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 12s 136ms/step - loss: 0.0017 - val_loss: 0.1103 - learning_rate: 0.0010
# Epoch 3/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - loss: 0.0013 - val_loss: 0.0911 - learning_rate: 0.0010
# Epoch 4/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - loss: 0.0010 - val_loss: 0.1228 - learning_rate: 0.0010
# Epoch 5/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - loss: 9.9601e-04 - val_loss: 0.1310 - learning_rate: 0.0010
# Epoch 6/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - loss: 8.8962e-04 - val_loss: 0.0942 - learning_rate: 0.0010
# Epoch 7/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - loss: 7.5512e-04 - val_loss: 0.0926 - learning_rate: 0.0010
# Epoch 8/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - loss: 6.8134e-04 - val_loss: 0.0717 - learning_rate: 0.0010
# Epoch 9/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - loss: 6.3883e-04 - val_loss: 0.0868 - learning_rate: 0.0010
# Epoch 10/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - loss: 5.2453e-04 - val_loss: 0.0851 - learning_rate: 0.0010
# Epoch 11/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - loss: 5.8201e-04 - val_loss: 0.1040 - learning_rate: 0.0010
# Epoch 12/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - loss: 5.4897e-04 - val_loss: 0.1398 - learning_rate: 0.0010
# Epoch 13/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - loss: 5.0471e-04 - val_loss: 0.1220 - learning_rate: 0.0010
# Epoch 14/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - loss: 3.2817e-04 - val_loss: 0.0969 - learning_rate: 3.0000e-04
# Epoch 15/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - loss: 3.3300e-04 - val_loss: 0.1016 - learning_rate: 3.0000e-04
# Epoch 16/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - loss: 3.3043e-04 - val_loss: 0.1064 - learning_rate: 3.0000e-04
# Epoch 17/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - loss: 3.3784e-04 - val_loss: 0.1121 - learning_rate: 3.0000e-04
# Epoch 18/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - loss: 3.1206e-04 - val_loss: 0.0981 - learning_rate: 3.0000e-04
# Epoch 19/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - loss: 2.7298e-04 - val_loss: 0.0982 - learning_rate: 9.0000e-05
# Epoch 20/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - loss: 2.8005e-04 - val_loss: 0.0960 - learning_rate: 9.0000e-05
# Epoch 21/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - loss: 2.7933e-04 - val_loss: 0.1014 - learning_rate: 9.0000e-05
# Epoch 22/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - loss: 2.9274e-04 - val_loss: 0.1086 - learning_rate: 9.0000e-05
# Epoch 23/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - loss: 2.8081e-04 - val_loss: 0.1073 - learning_rate: 9.0000e-05
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step

# %%
import joblib
joblib.dump(model, "model.pkl")
# Out:
# ['model.pkl']

# %%
evaluate_model(df_processed, actual, predictions, model, runs=50)
# Out:
# {'rmse': 40.96049088170076,
#  'mae': 34.19889942504042,
#  'mape': 13.196319544002552,
#  'direction_accuracy': 74.62235649546828,
#  'forecast_confidence': 71.55673357686646}

# %%
future_60 = forecast_future(model, df_processed, days=60)
plot_future(df_processed, future_60)
